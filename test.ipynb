# %%
import mne
from mne.io import read_raw_fif
from mne.datasets import sample
import matplotlib.pyplot as plt
# %matplotlib inline
from mne.channels import find_layout,read_ch_connectivity
import scipy.sparse

# %%
neuromag = read_raw_fif(sample.data_path() +
                          '/MEG/sample/sample_audvis_raw.fif')
type(neuromag)
# Out:
# Opening raw data file /home/likan_blk/anaconda2/lib/python2.7/site-packages/examples/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Current compensation grade : 0
# add_eeg_ref defaults to True in 0.13, will default to False in 0.14, and will be removed in 0.15. We recommend to use add_eeg_ref=False and set_eeg_reference() instead.
# Adding average EEG reference projection.
# 1 projection items deactivated
# <ipython-input-15-f620eb5f84a2>:2: DeprecationWarning: add_eeg_ref defaults to True in 0.13, will default to False in 0.14, and will be removed in 0.15. We recommend to use add_eeg_ref=False and set_eeg_reference() instead.
#   '/MEG/sample/sample_audvis_raw.fif')
# mne.io.fiff.raw.Raw

# %%
layout = find_layout(neuromag.info, ch_type='mag')
layout.plot()

# %%
neighboring_filename = 'neuromag306mag_neighb.mat'
neighboring,_ = read_ch_connectivity(neighboring_filename, picks=None)
type(neighboring.toarray())
# Out:
# numpy.ndarray

# %%
neighboring[1,1]
# Out:
# True
